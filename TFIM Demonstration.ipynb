# %%
from Heisenberg import Heisenberg
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test_object=Heisenberg("TFIM_input_file.txt")

# %%
test_object.generate_circuits()
# Out:
# Generating timestep 0 circuit
# Generating timestep 1 circuit
# Generating timestep 2 circuit
# Generating timestep 3 circuit
# Generating timestep 4 circuit
# Generating timestep 5 circuit
# Generating timestep 6 circuit
# Generating timestep 7 circuit
# Generating timestep 8 circuit
# Generating timestep 9 circuit
# Generating timestep 10 circuit
# Generating timestep 11 circuit
# Generating timestep 12 circuit
# Generating timestep 13 circuit
# Generating timestep 14 circuit
# Generating timestep 15 circuit
# Generating timestep 16 circuit
# Generating timestep 17 circuit
# Generating timestep 18 circuit
# Generating timestep 19 circuit
# Generating timestep 20 circuit
# Generating timestep 21 circuit
# Generating timestep 22 circuit
# Generating timestep 23 circuit
# Generating timestep 24 circuit
# Generating timestep 25 circuit
# Generating timestep 26 circuit
# Generating timestep 27 circuit
# Generating timestep 28 circuit
# Generating timestep 29 circuit
# Generating timestep 30 circuit
# Creating IBM quantum circuit objects...
# IBM quantum circuit objects created
# TFIM detected, enabling DS compiler
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qiskit_aer/noise/noise_model.py:380: UserWarning: Qiskit backend QasmSimulator('qasm_simulator') has no QubitProperties, so the resulting noise model will not include any thermal relaxation errors.
#   warn(

# %%
test_object.run_circuits()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qiskit_aer/noise/noise_model.py:380: UserWarning: Qiskit backend QasmSimulator('qasm_simulator') has no QubitProperties, so the resulting noise model will not include any thermal relaxation errors.
#   warn(
# Job Status: job has successfully run
# Post-processing qubit 1 data
# Post-processing qubit 2 data
# Post-processing qubit 3 data
# Done

# %%
noisyresults=test_object.results()

# %%
object2=Heisenberg("TFIM_input_file_clean.txt")
# Out:
# Invalid spin entered
# Invalid spin entered

# %%
object2.generate_circuits()
object2.run_circuits()
cleanresults=object2.results()
# Out:
# Generating timestep 0 circuit
# abc:  0.0
# Generating timestep 1 circuit
# abc:  0.25
# Generating timestep 2 circuit
# abc:  0.5
# Generating timestep 3 circuit
# abc:  0.75
# Generating timestep 4 circuit
# abc:  1.0
# Generating timestep 5 circuit
# abc:  1.25
# Generating timestep 6 circuit
# abc:  1.5
# Generating timestep 7 circuit
# abc:  1.75
# Generating timestep 8 circuit
# abc:  2.0
# Generating timestep 9 circuit
# abc:  2.25
# Generating timestep 10 circuit
# abc:  2.5
# Generating timestep 11 circuit
# abc:  2.75
# Generating timestep 12 circuit
# abc:  3.0
# Generating timestep 13 circuit
# abc:  3.25
# Generating timestep 14 circuit
# abc:  3.5
# Generating timestep 15 circuit
# abc:  3.75
# Generating timestep 16 circuit
# abc:  4.0
# Generating timestep 17 circuit
# abc:  4.25
# Generating timestep 18 circuit
# abc:  4.5
# Generating timestep 19 circuit
# abc:  4.75
# Generating timestep 20 circuit
# abc:  5.0
# Generating timestep 21 circuit
# abc:  5.25
# Generating timestep 22 circuit
# abc:  5.5
# Generating timestep 23 circuit
# abc:  5.75
# Generating timestep 24 circuit
# abc:  6.0
# Generating timestep 25 circuit
# abc:  6.25
# Generating timestep 26 circuit
# abc:  6.5
# Generating timestep 27 circuit
# abc:  6.75
# Generating timestep 28 circuit
# abc:  7.0
# Generating timestep 29 circuit
# abc:  7.25
# Generating timestep 30 circuit
# abc:  7.5
# Generating timestep 31 circuit
# abc:  7.75
# Generating timestep 32 circuit
# abc:  8.0
# Generating timestep 33 circuit
# abc:  8.25
# Generating timestep 34 circuit
# abc:  8.5
# Generating timestep 35 circuit
# abc:  8.75
# Generating timestep 36 circuit
# abc:  9.0
# Generating timestep 37 circuit
# abc:  9.25
# Generating timestep 38 circuit
# abc:  9.5
# Generating timestep 39 circuit
# abc:  9.75
# Generating timestep 40 circuit
# abc:  10.0
# Creating IBM quantum circuit objects...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qiskit_aer/noise/noise_model.py:380: UserWarning: Qiskit backend QasmSimulator('qasm_simulator') has no QubitProperties, so the resulting noise model will not include any thermal relaxation errors.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# IBM quantum circuit objects created
# Transpiling circuits...
# Circuits transpiled successfully
# Running noiseless simulator job...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qiskit_aer/noise/noise_model.py:380: UserWarning: Qiskit backend QasmSimulator('qasm_simulator') has no QubitProperties, so the resulting noise model will not include any thermal relaxation errors.
#   warn(
# Noiseless simulator job successful
# Post-processing qubit 1 data
# Post-processing qubit 2 data
# Done
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
cleanresults[0]
# Out:
# array([ 0.        +0.00000000e+00j, -0.65039527-3.12250226e-17j,
#        -0.53409651-2.77555756e-17j, -0.97717309+5.55111512e-17j,
#         0.13584028-1.73472348e-18j,  0.39803232+0.00000000e+00j,
#        -0.55361203-6.17995238e-18j, -1.17044728-2.08166817e-17j,
#        -0.5688008 +2.77555756e-17j, -0.30825172+5.89805982e-17j,
#         0.17334568+3.70797143e-17j, -0.17556545-4.11996826e-17j,
#        -1.58313427-8.67361738e-19j, -0.39647708-1.38777878e-17j,
#        -0.55269726-3.46944695e-18j,  0.37229236+5.89805982e-17j,
#        -0.34905662-2.60208521e-18j, -0.75240182+0.00000000e+00j,
#        -1.39786599-2.42861287e-17j,  0.50859442-2.08166817e-17j,
#        -0.09718116-5.63785130e-18j, -0.11311646-1.73472348e-18j,
#        -0.49140231-2.77555756e-17j, -1.19396905-6.93889390e-18j,
#        -0.17390222+6.93889390e-18j,  0.51824475-2.03830008e-17j,
#        -0.19164187-7.37257477e-18j, -0.96711349+3.46944695e-17j,
#        -0.65923613+0.00000000e+00j, -0.7481397 +2.77555756e-17j,
#         0.3169064 +1.12757026e-17j,  0.07077528-4.33680869e-18j,
#        -1.22444345+2.77555756e-17j, -0.71901803+1.38777878e-17j,
#        -0.84215672+1.38777878e-17j,  0.27196334+2.72134745e-17j,
#        -0.07756048+1.73472348e-17j, -0.51950773+8.67361738e-19j,
#        -1.58273185+3.46944695e-18j,  0.1623251 +2.08166817e-17j,
#        -0.37129264-9.97465999e-18j])

# %%
fig, ax = plt.subplots()
# plt.plot(noisyresults[2,:])
plt.plot(cleanresults[0],'k--')
plt.xlabel("Simulation Timestep",fontsize=14)
plt.ylabel("Average Magnetization",fontsize=14)
plt.legend(["Quantum Computer Results","Quantum Simulator Results"])
plt.tight_layout()
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if (n+1) % every_nth != 0:
        label.set_visible(False)
every_nth = 2
for n, label in enumerate(ax.yaxis.get_ticklabels()):
    if (n+1) % every_nth != 0:
        label.set_visible(False)

# %%
from ds_compiler import ds_compile
from qsee.core.state import ame, w, ghz
qc = ghz(3)
qc.measure_all()
uncompiled_circuits = [qc] #object2.circuits_list
compiled_circuits = []
for circuit in uncompiled_circuits:
    compiled_circuits.append(ds_compile(circuit,'ibm'))

# %%
qc.draw('mpl')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
qc.remove_final_measurements()
qc.draw('mpl')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
compiled_circuits[0].draw('mpl')
